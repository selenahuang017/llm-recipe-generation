# %% [markdown]
# # Imports/Setup:

# %%
import urllib3
import sys
from pathlib import Path
import os
import requests
import json

# Visualizations:
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Get path to project root
notebook_dir = Path.cwd()
project_root = notebook_dir.parents[1]
sys.path.insert(0, str(project_root))

from modules.Validator import Validator
from modules.Ollama import OllamaChatSession

# Settings:
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
sns.set_theme()

# %% [markdown]
# # Validation Test

# %%
class Args:
    val_model = 'gpt-oss:20b'
    verbose = True
    ingredients = 'white rice, rhubarb, persimmon, sesame seeds, gluten-free oreos, duck, tomatoes'
    allergens = 'gluten'
    check_budget = False
    calories = None

args = Args()
validator = Validator(args)
example_text = (project_root / 'example.txt').read_text()
validator.validate(example_text)
# Out:
# Check ingredients: True
# Check sections (breakfast): True
# Check allergens (breakfast): True
# Check sections (lunch): True
# Check allergens (lunch): True
# Check sections (dinner): True
# Check allergens (dinner): True
# === Validation Results ===
# ✓ Meal plan structure is correct: breakfast, lunch, and dinner recipes found
# ✓ All ingredients are used across the meal plan
# ✓ Breakfast: All sections present
# ✓ Breakfast: No allergens detected
# ✓ Lunch: All sections present
# ✓ Lunch: No allergens detected
# ✓ Dinner: All sections present
# ✓ Dinner: No allergens detected
# ✓ Nutritional information: Breakfast: 722.8 kcal, 10.8g protein, 7.6g fat, 154.5g carbs, 8.6g fiber | Lunch: 497.3 kcal, 26.5g protein, 24.0g fat, 44.9g carbs, 1.0g fiber | Dinner: 955.3 kcal, 46.7g protein, 35.0g fat, 115.4g carbs, 9.6g fiber | Total: 2175.5 kcal, 84.0g protein, 66.6g fat, 314.8g carbs, 19.2g fiber. Please update the nutritional information in section 5 to match calculated values: Breakfast: Calculated calories 722.8 kcal, stated 400.0 kcal (80.7% difference exceeds 10% tolerance) | Breakfast: Calculated protein 10.8 g, stated 7.0 g (53.9% difference exceeds 10% tolerance) | Breakfast: Calculated fat 7.6 g, stated 12.0 g (37.1% difference exceeds 10% tolerance) | Breakfast: Calculated carbohydrates 154.5 g, stated 70.0 g (120.8% difference exceeds 10% tolerance) | Breakfast: Calculated fiber 8.6 g, stated 4.0 g (115.6% difference exceeds 10% tolerance) | Lunch: Calculated fat 24.0 g, stated 28.0 g (14.2% difference exceeds 10% tolerance) | Lunch: Calculated carbohydrates 44.9 g, stated 35.0 g (28.4% difference exceeds 10% tolerance) | Lunch: Calculated fiber 1.0 g, stated 4.0 g (73.9% difference exceeds 10% tolerance) | Dinner: Calculated calories 955.3 kcal, stated 600.0 kcal (59.2% difference exceeds 10% tolerance) | Dinner: Calculated protein 46.7 g, stated 35.0 g (33.4% difference exceeds 10% tolerance) | Dinner: Calculated carbohydrates 115.4 g, stated 45.0 g (156.4% difference exceeds 10% tolerance) | Dinner: Calculated fiber 9.6 g, stated 5.0 g (91.6% difference exceeds 10% tolerance)
# =========================
# {'success': True,
#  'message': 'Meal plan structure is correct: breakfast, lunch, and dinner recipes found | All ingredients are used across the meal plan | Breakfast: All sections present | Breakfast: No allergens detected | Lunch: All sections present | Lunch: No allergens detected | Dinner: All sections present | Dinner: No allergens detected | Nutritional information: Breakfast: 722.8 kcal, 10.8g protein, 7.6g fat, 154.5g carbs, 8.6g fiber | Lunch: 497.3 kcal, 26.5g protein, 24.0g fat, 44.9g carbs, 1.0g fiber | Dinner: 955.3 kcal, 46.7g protein, 35.0g fat, 115.4g carbs, 9.6g fiber | Total: 2175.5 kcal, 84.0g protein, 66.6g fat, 314.8g carbs, 19.2g fiber. Please update the nutritional information in section 5 to match calculated values: Breakfast: Calculated calories 722.8 kcal, stated 400.0 kcal (80.7% difference exceeds 10% tolerance) | Breakfast: Calculated protein 10.8 g, stated 7.0 g (53.9% difference exceeds 10% tolerance) | Breakfast: Calculated fat 7.6 g, stated 12.0 g (37.1% difference exceeds 10% tolerance) | Breakfast: Calculated carbohydrates 154.5 g, stated 70.0 g (120.8% difference exceeds 10% tolerance) | Breakfast: Calculated fiber 8.6 g, stated 4.0 g (115.6% difference exceeds 10% tolerance) | Lunch: Calculated fat 24.0 g, stated 28.0 g (14.2% difference exceeds 10% tolerance) | Lunch: Calculated carbohydrates 44.9 g, stated 35.0 g (28.4% difference exceeds 10% tolerance) | Lunch: Calculated fiber 1.0 g, stated 4.0 g (73.9% difference exceeds 10% tolerance) | Dinner: Calculated calories 955.3 kcal, stated 600.0 kcal (59.2% difference exceeds 10% tolerance) | Dinner: Calculated protein 46.7 g, stated 35.0 g (33.4% difference exceeds 10% tolerance) | Dinner: Calculated carbohydrates 115.4 g, stated 45.0 g (156.4% difference exceeds 10% tolerance) | Dinner: Calculated fiber 9.6 g, stated 5.0 g (91.6% difference exceeds 10% tolerance)'}

# %% [markdown]
# # Full Recipe Generation:

# %%
# Initial request:
class Args:
    val_model = 'gpt-oss:20b'
    verbose = True

    ingredients = 'white rice, oranges, potatoes, gluten-free oreos, duck, ramen'
    allergens = 'gluten'
    budget = None
    check_budget = False
    calories = 2000

# Init Agent
args = Args()
validator = Validator(args)

# Get meal plan
meal_plan = validator.model.initial_request(args)
print('Meal plan:')
print(meal_plan)
# Out:
# Prompt: Create a meal plan with these ingredients: white rice, oranges, potatoes, gluten-free oreos, duck, ramen. All ingredients must be used across the three meals (breakfast, lunch, and dinner), but the recipes should be diverse and different from each other. Structure the meal plan as follows: BREAKFAST: [recipe format] LUNCH: [recipe format] DINNER: [recipe format] Put each recipe in this format: 1. Title, 2. Serving size, 3. Ingredients and amounts, 4. Instructions, 5. Nutritional information, 6. Anything else. Note to avoid these allergens: gluten.  Return the projected calories and aim for 2000. Indicate if over or under the projection.
# Meal plan:
# **BREAKFAST**
#
# 1. **Title** – Orange‑Rice Porridge with Oreo Crunch
# 2. **Serving size** – 1 person
# 3. **Ingredients & amounts**
#    - 3/4 cup cooked white rice (≈ 165 cal)
#    - 3/4 cup unsweetened almond milk (≈ 75 cal)
#    - 2 gluten‑free Oreos (≈ 140 cal)
#    - 1/2 orange – juice & zest (≈ 45 cal)
#    - 1 tsp honey (≈ 30 cal)
#    - Pinch of salt
# 4. **Instructions**
#    1. In a small saucepan, combine the cooked rice, almond milk, and a pinch of salt.
#    2. Warm over medium heat, stirring until the mixture thickens to a porridge‑like consistency (about 3 min).
#    3. Remove from heat, stir in orange juice and zest, then fold in honey.
#    5. Sprinkle the crumbled Oreos over the top just before serving.
# 5. **Nutritional information** – Approx. 535 kcal (protein ≈ 6 g, fat ≈ 8 g, carbs ≈ 95 g).
# 6. **Anything else** – Gluten‑free; no added wheat or rye products.
#
# ---
#
# **LUNCH**
#
# 1. **Title** – Duck & Ramen Stir‑Fry with Orange‑Glazed Potatoes
# 2. **Serving size** – 1 person
# 3. **Ingredients & amounts**
#    - 5 oz sliced duck breast (≈ 300 cal)
#    - 1.5 cups dry gluten‑free ramen noodles (≈ 450 cal)
#    - 1 medium potato, diced (≈ 110 cal)
#    - 1/2 orange – juice & zest (≈ 45 cal)
#    - 1 tsp olive oil (≈ 40 cal)
#    - 1 tbsp gluten‑free soy sauce (≈ 10 cal)
#    - 1 tsp honey (≈ 20 cal)
#    - Salt & pepper to taste
# 4. **Instructions**
#    1. Cook ramen according to package instructions (using gluten‑free noodles). Drain and set aside.
#    2. Heat the olive oil in a large skillet over medium‑high heat. Add duck breast slices, searing until browned and cooked through (~ 4–5 min). Remove and slice into bite‑sized pieces.
#    3. In the same skillet, toss diced potato, cooking until just tender and lightly crisp (≈ 7 min).
#    4. Return duck to the skillet, add the cooked ramen, orange juice & zest, soy sauce, and honey. Stir everything together, letting the sauce coat the noodles and potatoes (≈ 2 min).
#    5. Season with salt & pepper, serve hot.
# 5. **Nutritional information** – Approx. 945 kcal (protein ≈ 32 g, fat ≈ 32 g, carbs ≈ 120 g).
# 6. **Anything else** – Uses gluten‑free ramen; all other ingredients are naturally gluten‑free.
#
# ---
#
# **DINNER**
#
# 1. **Title** – Roasted Duck Thigh with Orange‑Glazed Potatoes
# 2. **Serving size** – 1 person
# 3. **Ingredients & amounts**
#    - 5 oz duck thigh, bone‑in (≈ 300 cal)
#    - 1 medium potato, cubed (≈ 110 cal)
#    - 1/2 orange – juice & zest (≈ 45 cal)
#    - 1 tsp olive oil (≈ 40 cal)
#    - 1 tsp honey (≈ 20 cal)
#    - Salt, pepper, and a pinch of smoked paprika
# 4. **Instructions**
#    1. Preheat the oven to 375 °F (190 °C).
#    2. Toss potato cubes with olive oil, salt, pepper, and paprika; spread on a baking sheet.
#    3. Place the duck thigh skin‑side up on the sheet and roast for 25–30 min, until the skin is crisp and the meat reaches an internal temperature of 165 °F (74 °C).
#    4. While the duck roasts, whisk orange juice, zest, and honey together.
#    5. Once the duck is done, remove from the oven and brush the orange glaze over the skin. Return to the oven for an additional 5 min to caramelize the glaze.
#    6. Serve the roasted duck alongside the glazed potatoes.
# 5. **Nutritional information** – Approx. 480 kcal (protein ≈ 24 g, fat ≈ 28 g, carbs ≈ 35 g).
# 6. **Anything else** – Entire dish is gluten‑free; no wheat, barley, or rye.
#
# ---
#
# ### Projected Daily Calorie Total
#
# - **Breakfast:** 535 kcal
# - **Lunch:** 945 kcal
# - **Dinner:** 480 kcal
# - **Total:** **1,960 kcal**
#
# **Result:** **Under the 2,000 kcal projection by ~40 kcal.**
# Feel free to add a small snack (e.g., a handful of nuts) if you’d like to reach closer to 2,000 kcal.
