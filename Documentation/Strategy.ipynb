# %% [markdown]
# # Workflow:
#
# 1) User inputs requirements to GUI
# 2) GUI structures requirements as JSON and passes them to Recipe Generator
# 3) Recipe Generator outputs a recipe to Validator
# 4) If recipe passes, send results to user. Otherwise loop back to Recipe Generator with feedback.

# %%
# Example of what the Generator receives from user/GUI:
user_request = {'User': True, 
                'Allergens': ['oxygen', 'water',],
                'Ingredients': ['oxygen', 'water',],
                
               }

# Example of what the Generator receives from Validator?
user_request = {'User': True, 
                'Allergens': False,

               }

# %% [markdown]
# # Key metrics:
#
# * Are the ingredients structured correctly?
#     * Quantity, Unit, Item, Preparation (optional)
#     * e.g. 1 cup Cremini Mushroom, diced
# * Is the recipe structured correctly?
# * Does the recipe meet the user's criteria?

# %% [markdown]
# # Evaluation Strategy:
#
# * Vibes and feelings
# * BLEU Score?

# %% [markdown]
# # Changelog/Lessons Learned/Key Takeaways:
#
# We tested stuff
